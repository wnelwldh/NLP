# %%
import matplotlib.pyplot as plt
import numpy as np
from mpl_toolkits.mplot3d import Axes3D
import scipy as sp
import scipy.linalg
import sympy as sy
from sympy.solvers.solveset import linsolve
from util.plot_helpers import plot_vec, plot_vecs, autoscale_arrows

sy.init_printing()
np.set_printoptions(precision=3)
np.set_printoptions(suppress=True)

# %% [markdown]
# Ax=b
# (i)해가 무수히 많이 존재
# (ii)해가 한개 존재하는 경우
# (iii)개하 존재아지 않는 경우
# 각각 A inverse 존재 여부

# %%
A = sy.Matrix([[0,1,4],[1,3,5],[3,7,7]])
x1, x2, x3 = sy.symbols('x1 x2 x3')
x= sy.Matrix([x1, x2, x3])

fig= plt.figure(figsize=(9,9))
ax = fig.add_subplot(111, projection='3d')


ax.scatter(-5,-2,6, s= 200, color ='red')


plot_vecs(A.col(0), A.col(1), A.col(2))
autoscale_arrows()
plt.show()

# %%
x1, x2, x3 = sy.symbols('x1 x2 x3')
A = sy.Matrix(((0,1,4),(1,3,5),(3,7,7)))
b = sy.Matrix((-5,-2,6))

system = A,b
linsolve(system, x1, x2, x3)
# Out:
# ∅

# %%
A= np.array([[0,1,4],[1,3,5],[3,7,7]])
b= np.array([5,-2,6])
A_inv= np.linalg.inv(A)
A_inv_b=A_inv@b
x= A_inv_b
print(x)

print(A@x)
print(b)
# Out:
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# <ipython-input-43-f549d3fb10f2> in <module>
#       1 A= np.array([[0,1,4],[1,3,5],[3,7,7]])
#       2 b= np.array([5,-2,6])
# ----> 3 A_inv= np.linalg.inv(A)
#       4 A_inv_b=A_inv@b
#       5 x= A_inv_b
#
# <__array_function__ internals> in inv(*args, **kwargs)
#
# c:\conda\envs\py368\lib\site-packages\numpy\linalg\linalg.py in inv(a)
#     544     signature = 'D->D' if isComplexType(t) else 'd->d'
#     545     extobj = get_linalg_error_extobj(_raise_linalgerror_singular)
# --> 546     ainv = _umath_linalg.inv(a, signature=signature, extobj=extobj)
#     547     return wrap(ainv.astype(result_t, copy=False))
#     548
#
# c:\conda\envs\py368\lib\site-packages\numpy\linalg\linalg.py in _raise_linalgerror_singular(err, flag)
#      86
#      87 def _raise_linalgerror_singular(err, flag):
# ---> 88     raise LinAlgError("Singular matrix")
#      89
#      90 def _raise_linalgerror_nonposdef(err, flag):
#
# LinAlgError: Singular matrix

# %% [markdown]
# 해가 없는경우
# inverse 존재 안함

# %%
A = sy.Matrix([[1,0,-3],[2,2,9],[0,1,5]])
x1, x2, x3 = sy.symbols('x1 x2 x3')
x= sy.Matrix([x1, x2, x3])
print('column vectors:', A.col(0), A.col(1), A.col(2))
fig= plt.figure(figsize=(9,9))
ax = fig.add_subplot(111, projection='3d')


ax.scatter(8,7,-2, s= 200, color ='red')
plot_vecs(A.col(0), A.col(1), A.col(2))
autoscale_arrows()
# Out:
# column vectors: Matrix([[1], [2], [0]]) Matrix([[0], [2], [1]]) Matrix([[-3], [9], [5]])

# %%
x1, x2, x3 = sy.symbols('x1 x2 x3')
A = sy.Matrix(((1,0,-3),(2,2,9),(0,1,5)))
b = sy.Matrix((8,7,-2))

system = A,b
linsolve(system, x1, x2, x3)
# Out:
# {(5, 3, -1)}

# %%
A= np.array([[1,0,-3],[2,2,9],[0,1,5]])
b= np.array([8,7,-2])
A_inv= np.linalg.inv(A)
A_inv_b=A_inv@b
x= A_inv_b
print(x)

print(A@x)
print(b)
# Out:
# [ 5.  3. -1.]
# [ 8.  7. -2.]
# [ 8  7 -2]

# %% [markdown]
# 해가 한 개 존재하는 경우
# inverse 존재

# %%
A = sy.Matrix([[1,2,3],[4,5,9],[9,12,21]])
x1, x2, x3 = sy.symbols('x1 x2 x3')
x= sy.Matrix([x1, x2, x3])
print('column vectors:', A.col(0), A.col(1), A.col(2))
fig= plt.figure(figsize=(9,9))
ax = fig.add_subplot(111, projection='3d')


ax.scatter(5,2,9, s= 200, color ='red')
plot_vecs(A.col(0), A.col(1), A.col(2))
autoscale_arrows()
# Out:
# column vectors: Matrix([[1], [4], [9]]) Matrix([[2], [5], [12]]) Matrix([[3], [9], [21]])

# %%
x1, x2, x3 = sy.symbols('x1 x2 x3')
A = sy.Matrix(((1,2,3),(4,5,9),(9,12,21)))
b = sy.Matrix((5,2,9))

system = A,b
linsolve(system, x1, x2, x3)
# Out:
# {(-x₃ - 7, 6 - x₃, x₃)}

# %%
A= np.array([[1,2,3],[4,5,9],[9,12,21]])
b= np.array([5,2,9])
A_inv= np.linalg.inv(A)
A_inv_b=A_inv@b
x= A_inv_b
print(x)

print(A@x)
print(b)
# Out:
# [  0.  20. -12.]
# [  4.  -8. -12.]
# [5 2 9]

# %% [markdown]
# 해가 무수히 많이 존재하는 경우
# inverse 존재
